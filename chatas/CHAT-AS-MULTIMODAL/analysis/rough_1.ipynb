# %%
import pandas as pd

# %%
df = pd.read_csv('../9Oct2024-1.txt', sep = '\t')

# %%
df.sort_values(by = 'id', inplace = True)

# %%
df[df['Result.OutputResult'].apply(lambda x: x[0] == ' ')]
# Out:
# Empty DataFrame
# Columns: [ROWID, id, context, prefix, Result.OutputResult, Result, Tokens, TimeTaken]
# Index: []

# %%
x
# Out:
# '[{\'description\': \'\', \'rationale\': \'\', \'shared_image\': [], \'speaker\': \'Andrik\', \'utterance\': "I\'m eagerly waiting on a bigger self-employed paycheck by the end of this month. Whoopeee", \'utterance_idx\': 0}, {\'description\': \'\', \'rationale\': \'\', \'shared_image\': [{\'caption\': \'person listening to music against a white background\', \'image_url\': \'https://ak1.picdn.net/shutterstock/videos/851851/thumb/1.jpg?i10c=img.resize(height:160)\'}, {\'caption\': \'boy singing into a microphone .\', \'image_url\': \'https://media.istockphoto.com/photos/boy-singing-into-a-microphone-very-emotional-picture-id476816708?k=6&m=476816708&s=612x612&w=0&h=nxEuL83NGh88_2BdUOMlmgVa8VGxtCj3PAWrfXOcu44=\'}, {\'caption\': \'portrait of a young man singing into microphone\', \'image_url\': \'https://media.istockphoto.com/photos/portrait-of-a-young-man-singing-into-microphone-picture-id692080690?k=6&m=692080690&s=612x612&w=0&h=h_hWoiv7T_K3C9GC1_DepxhN-4Fo2-ZSuPGQhEhrr-8=\'}], \'sp
# ...

# %%
class utterance:
    
class Dialog:
    def __init__(self, dialog: str):
        pass
# Out:
#   Cell In[5], line 3
#     class Dialog:
#     ^
# IndentationError: expected an indented block after class definition on line 1

# %%
x
# Out:
# '[{\'description\': \'\', \'rationale\': \'\', \'shared_image\': [], \'speaker\': \'Andrik\', \'utterance\': "I\'m eagerly waiting on a bigger self-employed paycheck by the end of this month. Whoopeee", \'utterance_idx\': 0}, {\'description\': \'\', \'rationale\': \'\', \'shared_image\': [{\'caption\': \'person listening to music against a white background\', \'image_url\': \'https://ak1.picdn.net/shutterstock/videos/851851/thumb/1.jpg?i10c=img.resize(height:160)\'}, {\'caption\': \'boy singing into a microphone .\', \'image_url\': \'https://media.istockphoto.com/photos/boy-singing-into-a-microphone-very-emotional-picture-id476816708?k=6&m=476816708&s=612x612&w=0&h=nxEuL83NGh88_2BdUOMlmgVa8VGxtCj3PAWrfXOcu44=\'}, {\'caption\': \'portrait of a young man singing into microphone\', \'image_url\': \'https://media.istockphoto.com/photos/portrait-of-a-young-man-singing-into-microphone-picture-id692080690?k=6&m=692080690&s=612x612&w=0&h=h_hWoiv7T_K3C9GC1_DepxhN-4Fo2-ZSuPGQhEhrr-8=\'}], \'sp
# ...

# %%
# Out:
# [{'description': '', 'rationale': '', 'shared_image': [], 'speaker': 'Andrik', 'utterance': "I'm eagerly waiting on a bigger self-employed paycheck by the end of this month. Whoopeee", 'utterance_idx': 0}, {'description': '', 'rationale': '', 'shared_image': [{'caption': 'person listening to music against a white background', 'image_url': 'https://ak1.picdn.net/shutterstock/videos/851851/thumb/1.jpg?i10c=img.resize(height:160)'}, {'caption': 'boy singing into a microphone .', 'image_url': 'https://media.istockphoto.com/photos/boy-singing-into-a-microphone-very-emotional-picture-id476816708?k=6&m=476816708&s=612x612&w=0&h=nxEuL83NGh88_2BdUOMlmgVa8VGxtCj3PAWrfXOcu44='}, {'caption': 'portrait of a young man singing into microphone', 'image_url': 'https://media.istockphoto.com/photos/portrait-of-a-young-man-singing-into-microphone-picture-id692080690?k=6&m=692080690&s=612x612&w=0&h=h_hWoiv7T_K3C9GC1_DepxhN-4Fo2-ZSuPGQhEhrr-8='}], 'speaker': 'Gena', 'utterance': 'Wow congrats! I recently 
# ...

# %%
import ast
import re
pattern = r'\{[^{}]*\}'
matches = re.findall(pattern, x)
dictionary = ast.literal_eval(matches[1])

# %%
dictionary
# Out:
# {'caption': 'person listening to music against a white background',
#  'image_url': 'https://ak1.picdn.net/shutterstock/videos/851851/thumb/1.jpg?i10c=img.resize(height:160)'}

# %%
json.loads(matches[0].replace("'", '"'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 json.loads(matches[0].replace("'", '"'))
#
# NameError: name 'json' is not defined

# %%
json.loads(x)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 json.loads(x)
#
# File ~/anaconda3/envs/penv/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/anaconda3/envs/penv/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
# ...

# %%
import json

# The input string
data_string = "[{'description': '', 'rationale': '', 'shared_image': [{'caption': 'diagram of a typical trench', 'image_url': 'http://images.slideplayer.com/26/8627768/slides/slide_10.jpg'}], 'speaker': 'Ahniyah', 'utterance': 'Help! Help!', 'utterance_idx': 0}]"

# Replace single quotes with double quotes for valid JSON
data_string = data_string.replace("'", '"')

# Parse the JSON string
data = json.loads(data_string)

# Accessing the data
print(data)
# Out:
# [{'description': '', 'rationale': '', 'shared_image': [{'caption': 'diagram of a typical trench', 'image_url': 'http://images.slideplayer.com/26/8627768/slides/slide_10.jpg'}], 'speaker': 'Ahniyah', 'utterance': 'Help! Help!', 'utterance_idx': 0}]

# %%
from
